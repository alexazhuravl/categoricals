# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/home/az/dev/atvisor/nlp/classifier/data/cat_2018.csv')
new_df = df[['Category ID (level 2)', 'Category Title (level 2)', 'Sub Category Title (level 3)']].copy()

#drop unneccesary columns - this step is already processed, so take care in the future!
cat_df_onehot = pd.get_dummies(new_df,
                               columns=['Category Title (level 2)'], prefix=['category'])

new_df.head(5)
res = pd.concat([cat_df_onehot, new_df], axis=1)

# %%
res.columns = res.columns.str.lower()

# %%
res.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>category id (level 2)</th>
#       <th>sub category title (level 3)</th>
#       <th>category_access stairs</th>
#       <th>category_alarms</th>
#       <th>category_ankle and wrist weights</th>
#       <th>category_anti slip mats</th>
#       <th>category_aprons and bibs</th>
#       <th>category_arm slings</th>
#       <th>category_arm supports</th>
#       <th>category_back support for bath</th>
#       <th>...</th>
#       <th>category_white boards</th>
#       <th>category_whiteboard reminders</th>
#       <th>category_wipers</th>
#       <th>category_wrist hold-down and supports</th>
# ...
